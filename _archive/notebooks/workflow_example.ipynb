# %%
import census
import pandas as pd

# %% [markdown]
# The process of running the `get_census` pipeline itself is fairly straight forward. The primary complexity comes in defining your variables and setting up the yaml document that is used by the DataPlan object to know how to assemble the data. A link to previously existing documentation on that can be found [here](https://github.com/NSAPH/data_requests/blob/master/request_projects/apr2020_tidy_census_confounders/readme.md).

# %% [markdown]
# The simple workflow of getting the data can be seen below. We do it with state geography to minimize the size of data.

# %%
plan = census.DataPlan("census_vars.yml", geometry="state", years=get_census.census_years(2000,2019))
plan.assemble_data()
print(plan.data)
# Out:
# 2000 hispanic_pct
# 2000 poverty
# 2000 poverty_mcare
# 2000 population
# 2000 median_house_value
# 2000 blk_pct
# 2000 white_pct
# 2000 native_pct
# 2000 asian_pct
# 2000 no_grad
# 2000 no_grad_mcare
# 2000 median_household_income
# 2000 owner_occupied
# 2000 median_age
# 2000 age_pct_0_14
# 2000 age_pct_15_44
# 2000 age_pct_45_65
# 2000 age_pct_65_plus
# 2009 hispanic_pct
# 2009 poverty
# 2009 poverty_mcare
# 2009 population
# 2009 median_house_value
# 2009 blk_pct
# 2009 white_pct
# 2009 native_pct
# 2009 asian_pct
# 2009 no_grad
# 2009 no_grad_mcare
# 2009 median_household_income
# 2009 owner_occupied
# 2009 median_age
# 2009 age_pct_0_14
# 2009 age_pct_15_44
# 2009 age_pct_45_65
# 2009 age_pct_65_plus
# 2010 hispanic_pct
# 2010 poverty
# 2010 poverty_mcare
# 2010 population
# 2010 median_house_value
# 2010 blk_pct
# 2010 white_pct
# 2010 native_pct
# 2010 asian_pct
# 2010 no_grad
# 2010 no_grad_mcare
# 2010 median_household_income
# 2010 owner_occupied
# 2010 median_age
# 2010 age_pct_0_14
# 2010 age_pct_15_44
# 2010 age_pct_45_65
# 2010 age_pct_65_plus
# 2011 hispanic_pct
# 2011 poverty
# 2011 poverty_mcare
# 2011 population
# 2011 median_house_value
# 2011 blk_pct
# 2011 white_pct
# 2011 native_pct
# 2011 asian_pct
# 2011 no_grad
# 2011 no_grad_mcare
# 2011 median_household_income
# 2011 owner_occupied
# 2011 median_age
# 2011 age_pct_0_14
# 2011 age_pct_15_44
# 2011 age_pct_45_65
# 2011 age_pct_65_plus
# 2012 hispanic_pct
# 2012 poverty
# 2012 poverty_mcare
# 2012 population
# 2012 median_house_value
# 2012 blk_pct
# 2012 white_pct
# 2012 native_pct
# 2012 asian_pct
# 2012 no_grad
# 2012 no_grad_mcare
# 2012 median_household_income
# 2012 owner_occupied
# 2012 median_age
# 2012 age_pct_0_14
# 2012 age_pct_15_44
# 2012 age_pct_45_65
# 2012 age_pct_65_plus
# 2013 hispanic_pct
# 2013 poverty
# 2013 poverty_mcare
# 2013 population
# 2013 median_house_value
# 2013 blk_pct
# 2013 white_pct
# 2013 native_pct
# 2013 asian_pct
# 2013 no_grad
# 2013 no_grad_mcare
# 2013 median_household_income
# 2013 owner_occupied
# 2013 median_age
# 2013 age_pct_0_14
# 2013 age_pct_15_44
# 2013 age_pct_45_65
# 2013 age_pct_65_plus
# 2014 hispanic_pct
# 2014 poverty
# 2014 poverty_mcare
# 2014 population
# 2014 median_house_value
# 2014 blk_pct
# 2014 white_pct
# 2014 native_pct
# 2014 asian_pct
# 2014 no_grad
# 2014 no_grad_mcare
# 2014 median_household_income
# 2014 owner_occupied
# 2014 median_age
# 2014 age_pct_0_14
# 2014 age_pct_15_44
# 2014 age_pct_45_65
# 2014 age_pct_65_plus
# 2015 hispanic_pct
# 2015 poverty
# 2015 poverty_mcare
# 2015 population
# 2015 median_house_value
# 2015 blk_pct
# 2015 white_pct
# 2015 native_pct
# 2015 asian_pct
# 2015 no_grad
# 2015 no_grad_mcare
# 2015 median_household_income
# 2015 owner_occupied
# 2015 median_age
# 2015 age_pct_0_14
# 2015 age_pct_15_44
# 2015 age_pct_45_65
# 2015 age_pct_65_plus
# 2016 hispanic_pct
# 2016 poverty
# 2016 poverty_mcare
# 2016 population
# 2016 median_house_value
# 2016 blk_pct
# 2016 white_pct
# 2016 native_pct
# 2016 asian_pct
# 2016 no_grad
# 2016 no_grad_mcare
# 2016 median_household_income
# 2016 owner_occupied
# 2016 median_age
# 2016 age_pct_0_14
# 2016 age_pct_15_44
# 2016 age_pct_45_65
# 2016 age_pct_65_plus
# 2017 hispanic_pct
# 2017 poverty
# 2017 poverty_mcare
# 2017 population
# 2017 median_house_value
# 2017 blk_pct
# 2017 white_pct
# 2017 native_pct
# 2017 asian_pct
# 2017 no_grad
# 2017 no_grad_mcare
# 2017 median_household_income
# 2017 owner_occupied
# 2017 median_age
# 2017 age_pct_0_14
# 2017 age_pct_15_44
# 2017 age_pct_45_65
# 2017 age_pct_65_plus
# 2018 hispanic_pct
# 2018 poverty
# 2018 poverty_mcare
# 2018 population
# 2018 median_house_value
# 2018 blk_pct
# 2018 white_pct
# 2018 native_pct
# 2018 asian_pct
# 2018 no_grad
# 2018 no_grad_mcare
# 2018 median_household_income
# 2018 owner_occupied
# 2018 median_age
# 2018 age_pct_0_14
# 2018 age_pct_15_44
# 2018 age_pct_45_65
# 2018 age_pct_65_plus
# 2019 hispanic_pct
# 2019 poverty
# 2019 poverty_mcare
# 2019 population
# 2019 median_house_value
# 2019 blk_pct
# 2019 white_pct
# 2019 native_pct
# 2019 asian_pct
# 2019 no_grad
# 2019 no_grad_mcare
# 2019 median_household_income
# 2019 owner_occupied
# 2019 median_age
# 2019 age_pct_0_14
# 2019 age_pct_15_44
# 2019 age_pct_45_65
# 2019 age_pct_65_plus
#     state  year  hispanic_pct   poverty  poverty_mcare  population  \
# 0      24  2000      0.043032  0.084943       0.085263     5296486
# 1      36  2000      0.151113  0.145920       0.113276    18976457
# 2      27  2000      0.029146  0.079363       0.081938     4919479
# 3      38  2000      0.012124  0.118633       0.111331      642200
# 4      37  2000      0.047080  0.122822       0.132285     8049313
# ..    ...   ...           ...       ...            ...         ...
# 619    53  2019      0.126630  0.108059       0.075358     7404107
# 620    54  2019      0.015610  0.175591       0.095053     1817305
# 621    55  2019      0.068108  0.113279       0.075510     5790716
# 622    56  2019      0.098690  0.109817       0.079732      581024
# 623    72  2019      0.987184  0.440517       0.392522     3318447
#
#      median_house_value   blk_pct  white_pct  native_pct  asian_pct   no_grad  \
# 0                146000  0.278942   0.640294    0.002912   0.039824  0.182200
# 1                148700  0.158849   0.679457    0.004345   0.055067  0.232546
# 2                122400  0.034908   0.894461    0.011173   0.028858  0.153595
# 3                 74400  0.006098   0.923670    0.048784   0.005615  0.165146
# 4                108300  0.215863   0.721137    0.012368   0.014124  0.232454
# ..                  ...       ...        ...         ...        ...       ...
# 619              339000  0.038044   0.753788    0.012756   0.085268  0.172347
# 620              119600  0.036862   0.930829    0.002018   0.007992  0.200488
# 621              180600  0.064103   0.854292    0.008875   0.027948  0.155327
# 622              220500  0.009607   0.914427    0.024378   0.008649  0.150313
# 623              111500  0.116523   0.659349    0.002061   0.001879  0.294745
#
#      no_grad_mcare  median_household_income  owner_occupied  median_age  \
# 0         0.343131                    52868        0.677358        36.0
# 1         0.356848                    43393        0.529863        35.9
# 2         0.313858                    47111        0.745525        35.4
# 3         0.421525                    34604        0.666139        36.2
# 4         0.415522                    39184        0.693597        35.3
# ..             ...                      ...             ...         ...
# 619       0.092271                    73775        0.629561        37.7
# 620       0.198683                    46711        0.731865        42.5
# 621       0.106906                    61747        0.670413        39.5
# 622       0.082220                    64049        0.703917        37.7
# 623       0.446641                    20539        0.681359        41.7
#
#      age_pct_0_14  age_pct_15_44  age_pct_45_65  age_pct_65_plus
# 0        0.214642       0.440844       0.231362         0.113152
# 1        0.206767       0.440729       0.223483         0.129021
# 2        0.215568       0.446016       0.217618         0.120799
# 3        0.202189       0.434463       0.216232         0.147116
# 4        0.205412       0.449476       0.224723         0.120389
# ..            ...            ...            ...              ...
# 619      0.185437       0.408421       0.255189         0.150953
# 620      0.167741       0.362877       0.275626         0.193756
# 621      0.182422       0.381636       0.271269         0.164672
# 622      0.197023       0.391917       0.253645         0.157415
# 623      0.156199       0.385686       0.261115         0.197001
#
# [624 rows x 20 columns]

# %% [markdown]
# The Census API speeds can vary a lot. Use the code in the following blocks to either save the plan object, or to load a saved plan object and start the walk through after the API query step

# %%
import pickle

# %% [markdown]
# Code to save:

# %%
with open("census_walkthrough_data.pkl", 'wb') as output:
    pickle.dump(plan, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Code to load:

# %%
with open("census_walkthrough_data.pkl", 'rb') as in_data:
    plan = pickle.load(in_data)

# %% [markdown]
# In honor of dorothy (and to get a better sense of the data) let's take a look at just the data for Kansas

# %%
plan.data[plan.data['state'] == "20"]
# Out:
#     state  year  hispanic_pct   poverty  poverty_mcare  population  \
# 13     20  2000      0.070023  0.098958       0.081171     2688418
# 68     20  2009      0.088059  0.122153       0.080468     2777835
# 122    20  2010      0.105163  0.124319       0.080980     2853118
# 172    20  2011      0.101590  0.126402       0.078475     2830985
# 224    20  2012      0.104741  0.132135       0.074834     2851183
# 276    20  2013      0.107430  0.137482       0.075590     2868107
# 328    20  2014      0.109659  0.137901       0.075432     2882946
# 380    20  2015      0.111725  0.135702       0.074327     2892987
# 432    20  2016      0.113080  0.132506       0.075375     2898292
# 511    20  2017      0.115317  0.128103       0.076390     2903820
# 564    20  2018      0.117099  0.123991       0.076461     2908776
# 588    20  2019      0.118764  0.119509       0.075321     2910652
#
#      median_house_value   blk_pct  white_pct  native_pct  asian_pct   no_grad  \
# 13                83500  0.057356   0.860708    0.009275   0.017410  0.180196
# 68               118500  0.056562   0.857649    0.008180   0.021684  0.195590
# 122              122600  0.068633   0.838055    0.020076   0.028496  0.193603
# 172              125500  0.057599   0.852249    0.008428   0.023855  0.189131
# 224              127400  0.057582   0.854120    0.008219   0.024089  0.184947
# 276              128400  0.057285   0.853968    0.008353   0.024549  0.182462
# 328              129400  0.058003   0.852536    0.008230   0.025171  0.179706
# 380              132000  0.058210   0.851910    0.008304   0.026150  0.176474
# 432              135300  0.057864   0.851854    0.008236   0.026776  0.175209
# 511              139200  0.058017   0.849060    0.008094   0.027804  0.172995
# 564              145400  0.058375   0.845929    0.008268   0.028717  0.170777
# 588              151900  0.058506   0.843775    0.008249   0.029476  0.169132
#
#      no_grad_mcare  median_household_income  owner_occupied  median_age  \
# 13        0.262679                    40624        0.692465        35.2
# 68        0.181598                    48394        0.694970        35.9
# 122       0.171623                    49424        0.677578        36.0
# 172       0.162217                    50594        0.689804        36.1
# 224       0.152831                    51273        0.682160        36.0
# 276       0.143891                    51332        0.675171        36.0
# 328       0.137959                    51872        0.671371        36.0
# 380       0.128367                    52205        0.666891        36.0
# 432       0.120945                    53571        0.663474        36.2
# 511       0.115076                    55477        0.664420        36.3
# 564       0.108194                    57422        0.663239        36.5
# 588       0.100415                    59597        0.662509        36.7
#
#      age_pct_0_14  age_pct_15_44  age_pct_45_65  age_pct_65_plus
# 13       0.218828       0.435010       0.213657         0.132505
# 68       0.208556       0.410696       0.250969         0.129779
# 122      0.212688       0.396993       0.258493         0.131826
# 172      0.211361       0.400310       0.256910         0.131419
# 224      0.211456       0.398145       0.257728         0.132671
# 276      0.211326       0.397344       0.256659         0.134671
# 328      0.210385       0.396973       0.255608         0.137033
# 380      0.209019       0.397416       0.253814         0.139750
# 432      0.207848       0.395862       0.252921         0.143370
# 511      0.206511       0.395940       0.250751         0.146797
# 564      0.205033       0.395808       0.248657         0.150502
# 588      0.203332       0.396066       0.246228         0.154373

# %% [markdown]
# What's happening under the covers is more interesting. We can output (part of) the plan to start to get a sense:

# %%
for k in plan.plan.keys():
    print(k)
    for i in range(3):
        print(plan.plan[k][i])
# Out:
# 2000
# Name: hispanic_pct
# Dataset: census
# Num: ['P004002']
# Den: ['P001001']
# Name: poverty
# Dataset: census
# Num: ['P087002']
# Den: ['P087001']
# Name: poverty_mcare
# Dataset: census
# Num: ['P087008', 'P087009']
# Den: ['P087008', 'P087009', 'P087016', 'P087017']
# 2009
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2010
# Name: hispanic_pct
# Dataset: census
# Num: ['P004003']
# Den: ['P004001']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2011
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2012
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2013
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2014
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2015
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2016
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2017
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2018
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']
# 2019
# Name: hispanic_pct
# Dataset: acs
# Num: ['B03003_003E']
# Den: ['B03003_001E']
# Name: poverty
# Dataset: acs
# Num: ['B17001_002E']
# Den: ['B17001_001E']
# Name: poverty_mcare
# Dataset: acs
# Num: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E']
# Den: ['B17001_015E', 'B17001_016E', 'B17001_029E', 'B17001_030E', 'B17001_044E', 'B17001_045E', 'B17001_058E', 'B17001_059E']

# %% [markdown]
# Here we see that each year has a set of variables that define a calculated outcome of census variables, along with the associated source. The source varies by year, and years without available data are skipped. These variables are defined in the `.yml` file used when creating the DataPlan object.

# %% [markdown]
# Looking at the data from kansas (and at the output from the data plan) we can see that the period from 2001-2009 has no data. Having this missing data be explicitly represented is important. To resolve this, we use the `DataPlan.create_missingness()` method. Note the shift to having to use `geoid` as the spatial identifier rather than state. The `geoid` variable is created to store all location information in a single variable rather than across multiple (like it comes when received from the census). `geoid` should generally correspond to the FIPS code, although this is only ensured for single variable codes and for county values (where an explicit case is defined).

# %%
plan.create_missingness()
plan.data[plan.data['geoid'] == "20"]
# Out:
#       year geoid state  hispanic_pct   poverty  poverty_mcare  population  \
# 13    2000    20    20      0.070023  0.098958       0.081171   2688418.0
# 65    2001    20   NaN           NaN       NaN            NaN         NaN
# 117   2002    20   NaN           NaN       NaN            NaN         NaN
# 169   2003    20   NaN           NaN       NaN            NaN         NaN
# 221   2004    20   NaN           NaN       NaN            NaN         NaN
# 273   2005    20   NaN           NaN       NaN            NaN         NaN
# 325   2006    20   NaN           NaN       NaN            NaN         NaN
# 377   2007    20   NaN           NaN       NaN            NaN         NaN
# 429   2008    20   NaN           NaN       NaN            NaN         NaN
# 481   2009    20    20      0.088059  0.122153       0.080468   2777835.0
# 533   2010    20    20      0.105163  0.124319       0.080980   2853118.0
# 585   2011    20    20      0.101590  0.126402       0.078475   2830985.0
# 637   2012    20    20      0.104741  0.132135       0.074834   2851183.0
# 689   2013    20    20      0.107430  0.137482       0.075590   2868107.0
# 741   2014    20    20      0.109659  0.137901       0.075432   2882946.0
# 793   2015    20    20      0.111725  0.135702       0.074327   2892987.0
# 845   2016    20    20      0.113080  0.132506       0.075375   2898292.0
# 897   2017    20    20      0.115317  0.128103       0.076390   2903820.0
# 949   2018    20    20      0.117099  0.123991       0.076461   2908776.0
# 1001  2019    20    20      0.118764  0.119509       0.075321   2910652.0
#
#       median_house_value   blk_pct  white_pct  ...  asian_pct   no_grad  \
# 13               83500.0  0.057356   0.860708  ...   0.017410  0.180196
# 65                   NaN       NaN        NaN  ...        NaN       NaN
# 117                  NaN       NaN        NaN  ...        NaN       NaN
# 169                  NaN       NaN        NaN  ...        NaN       NaN
# 221                  NaN       NaN        NaN  ...        NaN       NaN
# 273                  NaN       NaN        NaN  ...        NaN       NaN
# 325                  NaN       NaN        NaN  ...        NaN       NaN
# 377                  NaN       NaN        NaN  ...        NaN       NaN
# 429                  NaN       NaN        NaN  ...        NaN       NaN
# 481             118500.0  0.056562   0.857649  ...   0.021684  0.195590
# 533             122600.0  0.068633   0.838055  ...   0.028496  0.193603
# 585             125500.0  0.057599   0.852249  ...   0.023855  0.189131
# 637             127400.0  0.057582   0.854120  ...   0.024089  0.184947
# 689             128400.0  0.057285   0.853968  ...   0.024549  0.182462
# 741             129400.0  0.058003   0.852536  ...   0.025171  0.179706
# 793             132000.0  0.058210   0.851910  ...   0.026150  0.176474
# 845             135300.0  0.057864   0.851854  ...   0.026776  0.175209
# 897             139200.0  0.058017   0.849060  ...   0.027804  0.172995
# 949             145400.0  0.058375   0.845929  ...   0.028717  0.170777
# 1001            151900.0  0.058506   0.843775  ...   0.029476  0.169132
#
#       no_grad_mcare  median_household_income  owner_occupied  median_age  \
# 13         0.262679                  40624.0        0.692465        35.2
# 65              NaN                      NaN             NaN         NaN
# 117             NaN                      NaN             NaN         NaN
# 169             NaN                      NaN             NaN         NaN
# 221             NaN                      NaN             NaN         NaN
# 273             NaN                      NaN             NaN         NaN
# 325             NaN                      NaN             NaN         NaN
# 377             NaN                      NaN             NaN         NaN
# 429             NaN                      NaN             NaN         NaN
# 481        0.181598                  48394.0        0.694970        35.9
# 533        0.171623                  49424.0        0.677578        36.0
# 585        0.162217                  50594.0        0.689804        36.1
# 637        0.152831                  51273.0        0.682160        36.0
# 689        0.143891                  51332.0        0.675171        36.0
# 741        0.137959                  51872.0        0.671371        36.0
# 793        0.128367                  52205.0        0.666891        36.0
# 845        0.120945                  53571.0        0.663474        36.2
# 897        0.115076                  55477.0        0.664420        36.3
# 949        0.108194                  57422.0        0.663239        36.5
# 1001       0.100415                  59597.0        0.662509        36.7
#
#       age_pct_0_14  age_pct_15_44  age_pct_45_65  age_pct_65_plus
# 13        0.218828       0.435010       0.213657         0.132505
# 65             NaN            NaN            NaN              NaN
# 117            NaN            NaN            NaN              NaN
# 169            NaN            NaN            NaN              NaN
# 221            NaN            NaN            NaN              NaN
# 273            NaN            NaN            NaN              NaN
# 325            NaN            NaN            NaN              NaN
# 377            NaN            NaN            NaN              NaN
# 429            NaN            NaN            NaN              NaN
# 481       0.208556       0.410696       0.250969         0.129779
# 533       0.212688       0.396993       0.258493         0.131826
# 585       0.211361       0.400310       0.256910         0.131419
# 637       0.211456       0.398145       0.257728         0.132671
# 689       0.211326       0.397344       0.256659         0.134671
# 741       0.210385       0.396973       0.255608         0.137033
# 793       0.209019       0.397416       0.253814         0.139750
# 845       0.207848       0.395862       0.252921         0.143370
# 897       0.206511       0.395940       0.250751         0.146797
# 949       0.205033       0.395808       0.248657         0.150502
# 1001      0.203332       0.396066       0.246228         0.154373
#
# [20 rows x 21 columns]

# %%
plan.write_data("uninterpolated_state_census.csv")

# %%
plan.interpolate()
plan.data[plan.data['geoid'] == "20"]
# Out:
# Interpolating owner_occupied
# Interpolating median_household_income
# Interpolating age_pct_15_44
# Interpolating hispanic_pct
# Interpolating native_pct
# Interpolating no_grad_mcare
# Interpolating age_pct_45_65
# Interpolating median_house_value
# Interpolating poverty
# Interpolating blk_pct
# Interpolating no_grad
# Interpolating poverty_mcare
# Interpolating median_age
# Interpolating population
# Interpolating asian_pct
# Interpolating white_pct
# Interpolating age_pct_0_14
# Interpolating age_pct_65_plus
#       year geoid state  hispanic_pct   poverty  poverty_mcare    population  \
# 13    2000    20    20      0.070023  0.098958       0.081171  2.688418e+06
# 65    2001    20   NaN      0.070163  0.099138       0.081165  2.689111e+06
# 117   2002    20   NaN      0.070570  0.099661       0.081149  2.691128e+06
# 169   2003    20   NaN      0.072027  0.101536       0.081093  2.698353e+06
# 221   2004    20   NaN      0.076035  0.106690       0.080936  2.718224e+06
# 273   2005    20   NaN      0.087826  0.116896       0.080772  2.774302e+06
# 325   2006    20   NaN      0.093760  0.122875       0.080638  2.802929e+06
# 377   2007    20   NaN      0.094879  0.123379       0.080329  2.806937e+06
# 429   2008    20   NaN      0.095536  0.123963       0.079963  2.809887e+06
# 481   2009    20    20      0.088059  0.122153       0.080468  2.777835e+06
# 533   2010    20    20      0.105163  0.124319       0.080980  2.853118e+06
# 585   2011    20    20      0.101590  0.126402       0.078475  2.830985e+06
# 637   2012    20    20      0.104741  0.132135       0.074834  2.851183e+06
# 689   2013    20    20      0.107430  0.137482       0.075590  2.868107e+06
# 741   2014    20    20      0.109659  0.137901       0.075432  2.882946e+06
# 793   2015    20    20      0.111725  0.135702       0.074327  2.892987e+06
# 845   2016    20    20      0.113080  0.132506       0.075375  2.898292e+06
# 897   2017    20    20      0.115317  0.128103       0.076390  2.903820e+06
# 949   2018    20    20      0.117099  0.123991       0.076461  2.908776e+06
# 1001  2019    20    20      0.118764  0.119509       0.075321  2.910652e+06
#
#       median_house_value   blk_pct  white_pct  ...  asian_pct   no_grad  \
# 13          83500.000000  0.057356   0.860708  ...   0.017410  0.180196
# 65          83771.317829  0.057350   0.860685  ...   0.017443  0.180315
# 117         84560.606061  0.057332   0.860616  ...   0.017540  0.180662
# 169         87388.888889  0.057268   0.860368  ...   0.017885  0.181906
# 221         95166.666667  0.057092   0.859689  ...   0.018835  0.185327
# 273        110775.000000  0.059779   0.853515  ...   0.022319  0.191245
# 325        119866.666667  0.060586   0.851118  ...   0.023955  0.194928
# 377        120671.428571  0.060159   0.851279  ...   0.023940  0.194099
# 429        121120.000000  0.059988   0.851469  ...   0.023950  0.193489
# 481        118500.000000  0.056562   0.857649  ...   0.021684  0.195590
# 533        122600.000000  0.068633   0.838055  ...   0.028496  0.193603
# 585        125500.000000  0.057599   0.852249  ...   0.023855  0.189131
# 637        127400.000000  0.057582   0.854120  ...   0.024089  0.184947
# 689        128400.000000  0.057285   0.853968  ...   0.024549  0.182462
# 741        129400.000000  0.058003   0.852536  ...   0.025171  0.179706
# 793        132000.000000  0.058210   0.851910  ...   0.026150  0.176474
# 845        135300.000000  0.057864   0.851854  ...   0.026776  0.175209
# 897        139200.000000  0.058017   0.849060  ...   0.027804  0.172995
# 949        145400.000000  0.058375   0.845929  ...   0.028717  0.170777
# 1001       151900.000000  0.058506   0.843775  ...   0.029476  0.169132
#
#       no_grad_mcare  median_household_income  owner_occupied  median_age  \
# 13         0.262679             40624.000000        0.692465   35.200000
# 65         0.262051             40684.232558        0.692484   35.205426
# 117        0.260222             40859.454545        0.692541   35.221212
# 169        0.253670             41487.333333        0.692743   35.277778
# 221        0.235652             43214.000000        0.693300   35.433333
# 273        0.199374             46709.000000        0.689996   35.750000
# 325        0.178273             48737.333333        0.689172   35.933333
# 377        0.175979             49002.571429        0.689263   35.957143
# 429        0.174436             49153.933333        0.688789   35.960000
# 481        0.181598             48394.000000        0.694970   35.900000
# 533        0.171623             49424.000000        0.677578   36.000000
# 585        0.162217             50594.000000        0.689804   36.100000
# 637        0.152831             51273.000000        0.682160   36.000000
# 689        0.143891             51332.000000        0.675171   36.000000
# 741        0.137959             51872.000000        0.671371   36.000000
# 793        0.128367             52205.000000        0.666891   36.000000
# 845        0.120945             53571.000000        0.663474   36.200000
# 897        0.115076             55477.000000        0.664420   36.300000
# 949        0.108194             57422.000000        0.663239   36.500000
# 1001       0.100415             59597.000000        0.662509   36.700000
#
#       age_pct_0_14  age_pct_15_44  age_pct_45_65  age_pct_65_plus
# 13        0.218828       0.435010       0.213657         0.132505
# 65        0.218748       0.434822       0.213946         0.132484
# 117       0.218516       0.434273       0.214788         0.132422
# 169       0.217686       0.432309       0.217803         0.132202
# 221       0.215404       0.426905       0.226095         0.131597
# 273       0.212157       0.413349       0.243522         0.130973
# 325       0.209933       0.406128       0.253477         0.130462
# 377       0.210137       0.405297       0.253968         0.130598
# 429       0.210225       0.404820       0.254218         0.130737
# 481       0.208556       0.410696       0.250969         0.129779
# 533       0.212688       0.396993       0.258493         0.131826
# 585       0.211361       0.400310       0.256910         0.131419
# 637       0.211456       0.398145       0.257728         0.132671
# 689       0.211326       0.397344       0.256659         0.134671
# 741       0.210385       0.396973       0.255608         0.137033
# 793       0.209019       0.397416       0.253814         0.139750
# 845       0.207848       0.395862       0.252921         0.143370
# 897       0.206511       0.395940       0.250751         0.146797
# 949       0.205033       0.395808       0.248657         0.150502
# 1001      0.203332       0.396066       0.246228         0.154373
#
# [20 rows x 21 columns]

# %%
plan.write_data("interpolated_state_census.csv")
